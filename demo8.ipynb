# %% [markdown]
# ### Constructor in inheritance

# %%
class A:

    def __init__(self):
        print("in A init")
    def feature1(self):
        print("feature 1 is working")
    def feature2(self):
        print("feature 2 is working")


class B(A):
    def feature3(self):
        print("feature 3 is working")
    def feature4(self):
        print("feature 4 is working") 

a1 = B()
#even if the object is for class B, it's still calling the constructor of A class
# Out:
# in A init

# %%
class A:

    def __init__(self):
        print("in A init")
    def feature1(self):
        print("feature 1 is working")
    def feature2(self):
        print("feature 2 is working")


class B(A):

    def __init__(self):
        print("in B init")
    def feature3(self):
        print("feature 3 is working")
    def feature4(self):
        print("feature 4 is working") 

a1 = B()
a2 = A()
#here both class has init thats why the it's calling the init of class B as the object is from class B
# Out:
# in B init
# in A init

# %%
class A:

    def __init__(self):
        print("in A init")
    def feature1(self):
        print("feature 1 is working")
    def feature2(self):
        print("feature 2 is working")


class B(A):

    def __init__(self):
        super().__init__()
        print("in B init")
    def feature3(self):
        print("feature 3 is working")
    def feature4(self):
        print("feature 4 is working") 

a1 = B()
#what if I need to call the init of A class also, at that time I need to call super class to call the init of parent class
# Out:
# in A init
# in B init

# %%
class A:

    def __init__(self):
        print("in A init")
    def feature1(self):
        print("feature 1 is working")
    def feature2(self):
        print("feature 2 is working")


class B():

    def __init__(self):
        
        print("in B init")
    def feature1(self):
        print("feature 3 is working")
    def feature4(self):
        print("feature 4 is working") 

class C(B,A):
    def __init__(self):
        super().__init__()
        print("in C init")
a1 = C()
a1.feature1()
# here C is calling the class B init only because it works from left to right. as i wrote B,A that's why its calling B's init 
# method is same as init
# Out:
# in B init
# in C init
# feature 3 is working
