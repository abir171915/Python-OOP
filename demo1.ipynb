# %%
class Computer:
    def config(self):
        print("corei 15")

com1 = Computer() # Constructor
com2 = Computer()

# If i want to call any method i need to mention the class name and object name 
Computer.config(com1)
# Out:
# corei 15

# %%
com1.config()
com2.config()
# Out:
# corei 15
# corei 15
