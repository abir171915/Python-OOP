# %% [markdown]
# ### Inner class in python

# %%
class Student:
    def __init__(self, name, roll):
        self.name = name
        self.roll = roll
        self.lap = self.Laptop()


    def show(self):
        print(self.name, self.roll)

    class Laptop:
        def __init__(self):
            self.brand = 'HP'
            self.cpu = 'i5'
            self.ram = 8


s1 = Student('Mebin', 1)
s2 = Student('Abir', 2)

s1.show()
lap1 = s1.lap
lap2 = s2.lap
# Out:
# Mebin 1
# <__main__.Student.Laptop object at 0x0000029387A6B560>

# %%
#here we want to see that if we could make the laptop object outside of the student or not 

class Student:
    def __init__(self, name, roll):
        self.name = name
        self.roll = roll
        self.lap = self.Laptop()


    def show(self):
        print(self.name, self.roll)
        self.lap.show()

    class Laptop:
        def __init__(self):
            self.brand = 'HP'
            self.cpu = 'i5'
            self.ram = 8
        def show(self):
            print(self.brand, self.cpu, self.ram)


s1 = Student('Mebin', 1)
s2 = Student('Abir', 2)

s1.show()
# Out:
# Mebin 1
# HP i5 8
